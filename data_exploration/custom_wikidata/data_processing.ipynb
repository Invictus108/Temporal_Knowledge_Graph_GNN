# %%
import pandas as pd

PATH = r"C:\Users\jaden\Downloads\wikidata_temporal_rows_v2.csv"

# %%
# read from csv
df = pd.read_csv(PATH, dtype=str)

# %%
import pandas as pd

# If not already parsed, convert to datetime
df["start_dt"] = pd.to_datetime(df["start"], errors="coerce", utc=True)
df["end_dt"] = pd.to_datetime(df["end"], errors="coerce", utc=True)

has_start = df["start_dt"].notna()
has_end = df["end_dt"].notna()

only_start = (has_start & ~has_end).sum()
only_end = (~has_start & has_end).sum()
both = (has_start & has_end).sum()
neither = (~has_start & ~has_end).sum()

total = len(df)

print(f"Total rows: {total:,}")
print(f"Only start: {only_start:,}")
print(f"Only end:   {only_end:,}")
print(f"Both:       {both:,}")
print(f"Neither:    {neither:,}")
# Out:
# Total rows: 2,490,977
# Only start: 1,294,498
# Only end:   183,304
# Both:       977,367
# Neither:    35,808

# %%
# drop 
df = df[df["start"].notna() & df["end"].notna()].copy()
df.head()
# Out:
#   subject pred        obj                 start                   end  \
# 1     Q31  P38    Q232415  1830-01-01T00:00:00Z  2002-01-01T00:00:00Z
# 5     Q31  P35   Q1079522  1831-02-25T00:00:00Z  1831-07-20T00:00:00Z
# 6     Q31  P35     Q12971  1831-06-04T00:00:00Z  1865-12-10T00:00:00Z
# 7     Q31  P35     Q12967  1865-12-17T00:00:00Z  1909-12-17T00:00:00Z
# 8     Q31  P35  Q55008046  1909-12-23T00:00:00Z  1934-02-17T00:00:00Z
#
#                    start_dt                    end_dt
# 1 1830-01-01 00:00:00+00:00 2002-01-01 00:00:00+00:00
# 5 1831-02-25 00:00:00+00:00 1831-07-20 00:00:00+00:00
# 6 1831-06-04 00:00:00+00:00 1865-12-10 00:00:00+00:00
# 7 1865-12-17 00:00:00+00:00 1909-12-17 00:00:00+00:00
# 8 1909-12-23 00:00:00+00:00 1934-02-17 00:00:00+00:00

# %%
import bz2
import json
import re
from collections import defaultdict
from pathlib import Path
import os

import pandas as pd


DUMP_PATH = r"C:\Users\jaden\Downloads\latest-all.nt.bz2"
OUTPUT_JSON = r"C:\Users\jaden\Downloads\temporal_year_db.json"


LABEL_RE = re.compile(
    r'^<http://www\.wikidata\.org/entity/(Q\d+|P\d+)> '
    r'<http://www\.w3\.org/2000/01/rdf-schema#label> '
    r'"((?:[^"\\]|\\.)*)"@en \.$'
)

DESC_RE = re.compile(
    r'^<http://www\.wikidata\.org/entity/(Q\d+|P\d+)> '
    r'<http://schema\.org/description> '
    r'"((?:[^"\\]|\\.)*)"@en \.$'
)


def normalize_id(x):
    if pd.isna(x):
        return None
    s = str(x).strip()
    if s.startswith("http://www.wikidata.org/entity/"):
        s = s.rsplit("/", 1)[-1]
    return s


def year_from_value(x):
    if pd.isna(x):
        return None
    s = str(x).strip()
    if not s:
        return None

    i = 0
    if s[0] in "+-":
        i = 1

    digits = []
    while i < len(s) and s[i].isdigit():
        digits.append(s[i])
        i += 1

    if not digits:
        return None

    year = int("".join(digits))
    return -year if s[0] == "-" else year


def load_json_or_empty(path):
    """Load a JSON file if it exists, else return an empty dict."""
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            return json.load(f)
    return {}


def save_json_atomic(data, path):
    """Write JSON safely by using a temp file then replacing."""
    tmp_path = path + ".tmp"
    with open(tmp_path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    os.replace(tmp_path, path)


def decode_nt_string(s):
    """Decode escaped unicode sequences from N-Triples strings."""
    return bytes(s, "utf-8").decode("unicode_escape")


def q_entry_complete(x):
    """A Q cache entry is complete if it has both label and description."""
    return (
        isinstance(x, dict)
        and x.get("label") is not None
        and x.get("description") is not None
    )


def build_lookup_from_dump(
    dump_path,
    ids_needed,
    ent_cache_path,
    rel_cache_path,
    scan_dump=True,
    save_every=500_000,
):
    """
    Build a lookup for mixed Q and P ids.

    Parameters
    ----------
    dump_path : str
        Path to the bz2 Wikidata dump.
    ids_needed : iterable
        IDs like Q42, P31, etc.
    ent_cache_path : str
        JSON cache path for Q ids.
        Format:
            {
                "Q42": {"label": "...", "description": "..."}
            }
    rel_cache_path : str
        JSON cache path for P ids.
        Format:
            {
                "P31": "instance of"
            }
    scan_dump : bool
        If False:
            return only what is currently in the caches.
        If True:
            read caches first, then scan the dump for missing data and
            update caches as matches are found.
    save_every : int
        How many lines between periodic cache saves while scanning.

    Returns
    -------
    lookup : dict
        Mixed dictionary:
        - Q ids -> {"label": ..., "description": ...}
        - P ids -> "label"
    """

    # Normalize all requested ids
    normalized_ids = set()
    for x in ids_needed:
        nx = normalize_id(x)
        if nx is not None:
            normalized_ids.add(nx)

    # Split into entities and relations
    q_ids = {x for x in normalized_ids if x.startswith("Q")}
    p_ids = {x for x in normalized_ids if x.startswith("P")}

    # Load caches
    ent_cache = load_json_or_empty(ent_cache_path)
    rel_cache = load_json_or_empty(rel_cache_path)

    # --- clean entity cache (Q) ---
    BAD_ID_RE = re.compile(r'^[QP]\d+$')

    clean_ent_cache = {}
    for k, v in ent_cache.items():
        if not k.startswith("Q"):
            continue
        if not isinstance(v, dict):
            continue

        label = v.get("label")
        desc = v.get("description")

        # filter out labels/descriptions that are just IDs like "Q4"
        if isinstance(label, str) and BAD_ID_RE.match(label):
            label = None
        if isinstance(desc, str) and BAD_ID_RE.match(desc):
            desc = None

        clean_ent_cache[k] = {"label": label, "description": desc}

    ent_cache = clean_ent_cache


    # --- clean relation cache (P) ---
    clean_rel_cache = {}
    for k, v in rel_cache.items():
        if not k.startswith("P"):
            continue
        if not isinstance(v, str):
            continue

        # filter out values like "Q4" or "P31"
        if BAD_ID_RE.match(v):
            continue

        clean_rel_cache[k] = v

    rel_cache = clean_rel_cache

    # Build initial lookup from cache contents
    lookup = {}

    missing_q = set()
    for qid in q_ids:
        cached = ent_cache.get(qid)
        if isinstance(cached, dict):
            lookup[qid] = {
                "label": cached.get("label"),
                "description": cached.get("description"),
            }
        else:
            lookup[qid] = {"label": None, "description": None}

        if not q_entry_complete(lookup[qid]):
            missing_q.add(qid)

    missing_p = set()
    for pid in p_ids:
        cached = rel_cache.get(pid)
        if isinstance(cached, str) and cached:
            lookup[pid] = cached
        else:
            lookup[pid] = None
            missing_p.add(pid)

    # If caller only wants cached contents, stop here
    if not scan_dump:
        return lookup

    # If cache already had everything, no need to scan
    if not missing_q and not missing_p:
        return lookup

    lines_processed = 0
    last_save_line = 0

    try:
        with bz2.open(dump_path, "rt", encoding="utf-8") as f:
            for line in f:
                lines_processed += 1

                # Cheap filter before regex
                if "wikidata.org/entity/" not in line:
                    continue

                # First try label lines
                m = LABEL_RE.match(line)
                if m:
                    eid, raw_label = m.groups()
                    label = decode_nt_string(raw_label)

                    # Property label
                    if eid in missing_p:
                        rel_cache[eid] = label
                        lookup[eid] = label
                        missing_p.remove(eid)

                    # Entity label
                    elif eid in missing_q:
                        if eid not in ent_cache or not isinstance(ent_cache[eid], dict):
                            ent_cache[eid] = {"label": None, "description": None}

                        ent_cache[eid]["label"] = label
                        lookup[eid]["label"] = label

                        if q_entry_complete(ent_cache[eid]):
                            missing_q.remove(eid)

                else:
                    # Then try description lines for Q ids
                    m = DESC_RE.match(line)
                    if m:
                        eid, raw_desc = m.groups()

                        if eid in missing_q:
                            desc = decode_nt_string(raw_desc)

                            if eid not in ent_cache or not isinstance(ent_cache[eid], dict):
                                ent_cache[eid] = {"label": None, "description": None}

                            ent_cache[eid]["description"] = desc
                            lookup[eid]["description"] = desc

                            if q_entry_complete(ent_cache[eid]):
                                missing_q.remove(eid)

                # Stop early once everything is found
                if not missing_q and not missing_p:
                    break

                # Periodically save caches during long scans
                if lines_processed - last_save_line >= save_every:
                    try:
                        save_json_atomic(ent_cache, ent_cache_path)
                        save_json_atomic(rel_cache, rel_cache_path)
                        last_save_line = lines_processed
                        print(
                            f"Processed {lines_processed:,} lines | "
                            f"remaining Q: {len(missing_q):,} | "
                            f"remaining P: {len(missing_p):,}"
                        )
                    except:
                        print("Failed. Will upload next time")

    except EOFError:
        print("Warning: dump appears truncated; returning partial lookup.")

    # Final save after scan
    save_json_atomic(ent_cache, ent_cache_path)
    save_json_atomic(rel_cache, rel_cache_path)

    return lookup


def build_year_json(df, dump_path, output_json_path):
    required = {"subject", "pred", "obj", "start", "end"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"Missing required columns: {sorted(missing)}")

    df = df.copy()
    df["subject"] = df["subject"].map(normalize_id)
    df["pred"] = df["pred"].map(normalize_id)
    df["obj"] = df["obj"].map(normalize_id)

    df = df[df["start"].notna() & df["end"].notna()].copy()

    ids_needed = set(df["subject"]) | set(df["pred"]) | set(df["obj"])
    print(f"Need to resolve {len(ids_needed):,} unique subject/predicate IDs from dump...")

    ent_cache_path = "wikidata_entity_label_cache.json"
    rel_cache_path = "wikidata_relation_label_cache.json"

    lookup = build_lookup_from_dump(dump_path, ids_needed, ent_cache_path, rel_cache_path, scan_dump=True, save_every=500_000)

    def subject_info(qid):
        info = lookup.get(qid)
        if not info:
            return None
        label = info.get("label")
        description = info.get("description")
        if not label or not description:
            return None
        return {"label": label, "description": description}

    def relation_text(pid):
        info = lookup.get(pid)
        if not info:
            return None
        return info  # already a string


    df["head"] = df["subject"].map(subject_info)
    df["relation"] = df["pred"].map(relation_text)
    df["tail"] = df["obj"].map(subject_info)
    df["start_year"] = df["start"].map(year_from_value)
    df["end_year"] = df["end"].map(year_from_value)

    print("head:", df["head"].notna().sum())
    print("relation:", df["relation"].notna().sum())
    print("tail:", df["tail"].notna().sum())
    print("start_year:", df["start_year"].notna().sum())
    print("end_year:", df["end_year"].notna().sum())
    print("total rows:", len(df))

    print("head & relation:", (df["head"].notna() & df["relation"].notna()).sum())
    print("years ok:", (df["start_year"].notna() & df["end_year"].notna()).sum())

    df = df[
        df["head"].notna()
        & df["relation"].notna()
        & df["tail"].notna()
        & df["start_year"].notna()
        & df["end_year"].notna()
    ].copy()

    print(f"Rows with everything: {len(df)}")


    df["start_year"] = df["start_year"].astype(int)
    df["end_year"] = df["end_year"].astype(int)
    df = df[df["start_year"] <= df["end_year"]].copy()

    year_db = defaultdict(list)
    month_db = defaultdict(list)


    def parse_year_month(x):
        """
        Handles strings like:
        1843-##-##
        1843-05-##
        1843-05-01T00:00:00Z
        +1843-05-01T00:00:00Z

        Returns:
        (year, month) where month can be None if unknown
        """
        s = str(x).strip()

        if s[0] == "+":
            s = s[1:]

        year = int(s[:4])

        month = None
        if len(s) >= 7:
            mm = s[5:7]
            if mm.isdigit() and mm != "00":
                month = int(mm)

        return year, month


    for _, row in df.iterrows():
        triple = {
            "head": row["head"],
            "relation": row["relation"],
            "tail": row["tail"],
            "start": row["start"],
            "end": row["end"],
        }

        start_year, start_month = parse_year_month(row["start"])
        end_year, end_month = parse_year_month(row["end"])

        # Fill missing months for interval expansion
        start_month = 1 if start_month is None else start_month
        end_month = 12 if end_month is None else end_month

        # Year DB
        for year in range(start_year, end_year + 1):
            year_db[str(year)].append(triple)

        # Month DB
        y, m = start_year, start_month
        while (y < end_year) or (y == end_year and m <= end_month):
            month_db[f"{y:04d}-{m:02d}"].append(triple)

            m += 1
            if m == 13:
                m = 1
                y += 1

    year_db = dict(year_db)
    month_db = dict(month_db)

    output_json_path = Path(output_json_path)
    with open(output_json_path, "w", encoding="utf-8") as f:
        json.dump(year_db, f, indent=2, ensure_ascii=False)
    
    output_json_path_monthly = output_json_path.with_name(
        output_json_path.stem + "_monthly.json"
    )
    with open(output_json_path_monthly, "w", encoding="utf-8") as f:
        json.dump(month_db, f, indent=2, ensure_ascii=False)

    print(f"Saved JSON DB to: {output_json_path}. _monthly for monthly one")
    print(f"Rows kept: {len(df):,}")
    print(f"Years written: {len(year_db):,}")
    print(f"Months written: {len(month_db):,}")
    print(f"Total triples: {sum(len(v) for v in year_db.values()):,}")
    

    return year_db, df, lookup


year_db, filtered_df, lookup = build_year_json(
    df=df,
    dump_path=DUMP_PATH,
    output_json_path=OUTPUT_JSON,
)
# Out:
# Need to resolve 553,782 unique subject/predicate IDs from dump...
# Processed 500,004 lines | remaining Q: 426,207 | remaining P: 217
# Processed 1,000,004 lines | remaining Q: 426,200 | remaining P: 217
# Processed 1,500,004 lines | remaining Q: 426,197 | remaining P: 217
# Processed 2,000,004 lines | remaining Q: 426,191 | remaining P: 217
# Processed 2,500,004 lines | remaining Q: 426,188 | remaining P: 217
# Processed 3,000,006 lines | remaining Q: 426,184 | remaining P: 217
# Processed 141,000,151 lines | remaining Q: 424,479 | remaining P: 217
# Processed 141,500,153 lines | remaining Q: 424,465 | remaining P: 217
# Processed 142,000,153 lines | remaining Q: 424,451 | remaining P: 217
# Processed 142,500,153 lines | remaining Q: 424,434 | remaining P: 217
# Processed 143,000,153 lines | remaining Q: 424,430 | remaining P: 217
# Processed 143,500,153 lines | remaining Q: 424,428 | remaining P: 217
# Processed 144,000,153 lines | remaining Q: 424,421 | remaining P: 217
# Processed 144,500,154 lines | remaining Q: 424,418 | remaining P: 217
# Processed 145,000,154 lines | remaining Q: 424,414 | remaining P: 217
# Processed 145,500,157 lines | remaining Q: 424,409 | remaining P: 217
# Processed 146,000,157 lines | remaining Q: 424,406 | remaining P: 217
# Processed 146,500,159 lines | remaining Q: 424,400 | remaining P: 217
# Processed 147,000,159 lines | remaining Q: 424,398 | remaining P: 217
# Processed 147,500,159 lines | remaining Q: 424,392 | remaining P: 217
# Processed 148,000,159 lines | remaining Q: 424,392 | remaining P: 217
# Processed 148,500,159 lines | remaining Q: 424,386 | remaining P: 217
# Processed 149,000,161 lines | remaining Q: 424,381 | remaining P: 217
# Processed 149,500,161 lines | remaining Q: 424,374 | remaining P: 217
# Processed 150,000,161 lines | remaining Q: 424,367 | remaining P: 217
# Processed 150,500,161 lines | remaining Q: 424,365 | remaining P: 217
# Processed 151,000,162 lines | remaining Q: 424,364 | remaining P: 217
# Processed 151,500,162 lines | remaining Q: 424,361 | remaining P: 217
# Processed 152,000,162 lines | remaining Q: 424,358 | remaining P: 217
# Processed 152,500,164 lines | remaining Q: 424,357 | remaining P: 217
# Processed 153,000,164 lines | remaining Q: 424,356 | remaining P: 217
# Processed 153,500,164 lines | remaining Q: 424,351 | remaining P: 217
# Processed 154,000,164 lines | remaining Q: 424,348 | remaining P: 217
# Processed 154,500,164 lines | remaining Q: 424,339 | remaining P: 217
# Processed 155,000,164 lines | remaining Q: 424,331 | remaining P: 217
# Processed 155,500,164 lines | remaining Q: 424,322 | remaining P: 217
# Processed 156,000,164 lines | remaining Q: 424,320 | remaining P: 217
# Processed 156,500,164 lines | remaining Q: 424,313 | remaining P: 217
# Processed 157,000,164 lines | remaining Q: 424,305 | remaining P: 217
# Processed 157,500,164 lines | remaining Q: 424,302 | remaining P: 217
# Processed 158,000,164 lines | remaining Q: 424,300 | remaining P: 217
# Processed 158,500,164 lines | remaining Q: 424,298 | remaining P: 217
# Processed 159,000,164 lines | remaining Q: 424,290 | remaining P: 217
# Processed 159,500,164 lines | remaining Q: 424,287 | remaining P: 217
# Processed 160,000,168 lines | remaining Q: 424,278 | remaining P: 217
# Processed 160,500,168 lines | remaining Q: 424,275 | remaining P: 217
# Processed 161,000,168 lines | remaining Q: 424,270 | remaining P: 217
# Processed 161,500,168 lines | remaining Q: 424,262 | remaining P: 217
# Processed 162,000,168 lines | remaining Q: 424,257 | remaining P: 217
# Processed 162,500,168 lines | remaining Q: 424,255 | remaining P: 217
# Processed 163,000,168 lines | remaining Q: 424,254 | remaining P: 217
# Processed 163,500,168 lines | remaining Q: 424,251 | remaining P: 217
# Processed 5,754,504,840 lines | remaining Q: 144,030 | remaining P: 191
# Processed 5,755,004,840 lines | remaining Q: 144,028 | remaining P: 191
# Processed 5,755,504,840 lines | remaining Q: 144,025 | remaining P: 191
# Processed 5,756,004,840 lines | remaining Q: 144,023 | remaining P: 191
# Processed 5,756,504,840 lines | remaining Q: 144,022 | remaining P: 191
# Processed 5,757,004,840 lines | remaining Q: 144,020 | remaining P: 191
# Processed 5,757,504,840 lines | remaining Q: 144,020 | remaining P: 191
# Processed 5,758,004,840 lines | remaining Q: 144,017 | remaining P: 191
# Processed 5,758,504,840 lines | remaining Q: 144,014 | remaining P: 191
# Processed 5,759,004,842 lines | remaining Q: 144,013 | remaining P: 191
# Processed 5,759,504,842 lines | remaining Q: 144,010 | remaining P: 191
# Processed 5,760,004,842 lines | remaining Q: 144,007 | remaining P: 191
# Processed 5,760,504,842 lines | remaining Q: 144,006 | remaining P: 191
# Processed 5,761,004,842 lines | remaining Q: 144,005 | remaining P: 191
# Processed 5,761,504,843 lines | remaining Q: 144,005 | remaining P: 191
# Processed 5,762,004,851 lines | remaining Q: 144,003 | remaining P: 191
# Processed 5,762,504,851 lines | remaining Q: 144,003 | remaining P: 190
# Processed 5,763,004,851 lines | remaining Q: 144,003 | remaining P: 190
# Processed 5,763,504,851 lines | remaining Q: 144,002 | remaining P: 190
# Processed 5,764,004,851 lines | remaining Q: 144,001 | remaining P: 190
# Processed 5,764,504,851 lines | remaining Q: 143,998 | remaining P: 190
# Processed 5,765,004,851 lines | remaining Q: 143,997 | remaining P: 190
# Processed 5,765,504,851 lines | remaining Q: 143,997 | remaining P: 190
# Processed 5,766,004,851 lines | remaining Q: 143,997 | remaining P: 190
# Processed 5,766,504,856 lines | remaining Q: 143,995 | remaining P: 190
# Processed 5,767,004,856 lines | remaining Q: 143,991 | remaining P: 190
# Processed 5,767,504,856 lines | remaining Q: 143,989 | remaining P: 190
# Processed 5,768,004,856 lines | remaining Q: 143,986 | remaining P: 190
# Processed 5,768,504,856 lines | remaining Q: 143,983 | remaining P: 190
# Processed 5,769,004,856 lines | remaining Q: 143,983 | remaining P: 190
# Processed 5,769,504,856 lines | remaining Q: 143,983 | remaining P: 190
# Processed 5,770,004,856 lines | remaining Q: 143,981 | remaining P: 190
# Processed 5,770,504,856 lines | remaining Q: 143,981 | remaining P: 190
# Processed 5,771,004,856 lines | remaining Q: 143,973 | remaining P: 190
# Processed 5,771,504,856 lines | remaining Q: 143,961 | remaining P: 190
# Processed 5,772,004,856 lines | remaining Q: 143,961 | remaining P: 189
# Processed 5,772,504,856 lines | remaining Q: 143,959 | remaining P: 189
# Processed 5,773,004,856 lines | remaining Q: 143,958 | remaining P: 189
# Processed 5,773,504,858 lines | remaining Q: 143,956 | remaining P: 189
# Processed 5,774,004,858 lines | remaining Q: 143,952 | remaining P: 189
# Processed 5,774,504,858 lines | remaining Q: 143,948 | remaining P: 189
# Processed 5,775,004,858 lines | remaining Q: 143,946 | remaining P: 189
# Processed 5,775,504,858 lines | remaining Q: 143,943 | remaining P: 189
# Processed 5,776,004,859 lines | remaining Q: 143,940 | remaining P: 189
# Processed 5,776,504,859 lines | remaining Q: 143,937 | remaining P: 189
# Processed 5,777,004,859 lines | remaining Q: 143,936 | remaining P: 189
# Processed 5,777,504,859 lines | remaining Q: 143,933 | remaining P: 189
# Processed 5,778,004,859 lines | remaining Q: 143,932 | remaining P: 189
# Processed 5,778,504,859 lines | remaining Q: 143,929 | remaining P: 189
# Processed 5,779,004,859 lines | remaining Q: 143,928 | remaining P: 189
# Processed 5,779,504,859 lines | remaining Q: 143,928 | remaining P: 189
# Processed 5,780,004,859 lines | remaining Q: 143,928 | remaining P: 189
# Processed 5,780,504,859 lines | remaining Q: 143,927 | remaining P: 189
# Processed 5,781,004,859 lines | remaining Q: 143,927 | remaining P: 189
# Processed 5,781,504,859 lines | remaining Q: 143,927 | remaining P: 189
# Processed 5,782,004,859 lines | remaining Q: 143,926 | remaining P: 189
# Processed 5,782,504,859 lines | remaining Q: 143,926 | remaining P: 189
# Processed 5,783,004,859 lines | remaining Q: 143,926 | remaining P: 189
# Processed 5,783,504,859 lines | remaining Q: 143,925 | remaining P: 189
# Processed 5,784,004,859 lines | remaining Q: 143,921 | remaining P: 189
# Processed 5,784,504,859 lines | remaining Q: 143,915 | remaining P: 189
# Processed 5,785,004,859 lines | remaining Q: 143,914 | remaining P: 189
# Processed 5,785,504,859 lines | remaining Q: 143,914 | remaining P: 189
# Processed 5,786,004,859 lines | remaining Q: 143,910 | remaining P: 189
# Processed 5,786,504,859 lines | remaining Q: 143,904 | remaining P: 189
# Processed 5,787,004,859 lines | remaining Q: 143,904 | remaining P: 189
# Processed 5,787,504,859 lines | remaining Q: 143,904 | remaining P: 189
# Processed 5,788,004,859 lines | remaining Q: 143,902 | remaining P: 189
# Processed 5,788,504,859 lines | remaining Q: 143,900 | remaining P: 189
# Processed 5,789,004,859 lines | remaining Q: 143,899 | remaining P: 189
# Processed 5,789,504,861 lines | remaining Q: 143,897 | remaining P: 189
# Processed 5,790,004,861 lines | remaining Q: 143,886 | remaining P: 189
# Processed 5,790,504,861 lines | remaining Q: 143,884 | remaining P: 189
# Processed 5,791,004,861 lines | remaining Q: 143,878 | remaining P: 189
# Processed 5,791,504,861 lines | remaining Q: 143,868 | remaining P: 189
# Processed 5,792,004,861 lines | remaining Q: 143,868 | remaining P: 189
# Processed 5,792,504,861 lines | remaining Q: 143,865 | remaining P: 189
# Processed 5,793,004,861 lines | remaining Q: 143,861 | remaining P: 189
# Processed 5,793,504,861 lines | remaining Q: 143,857 | remaining P: 189
# Processed 5,794,004,865 lines | remaining Q: 143,855 | remaining P: 189
# Processed 5,794,504,865 lines | remaining Q: 143,851 | remaining P: 189
# Processed 5,795,004,865 lines | remaining Q: 143,850 | remaining P: 189
# Processed 5,795,504,865 lines | remaining Q: 143,850 | remaining P: 189
# Processed 5,796,004,865 lines | remaining Q: 143,850 | remaining P: 189
# Processed 5,796,504,865 lines | remaining Q: 143,849 | remaining P: 189
# Processed 5,797,004,865 lines | remaining Q: 143,848 | remaining P: 189
# Processed 5,797,504,865 lines | remaining Q: 143,848 | remaining P: 189
# Processed 5,798,004,865 lines | remaining Q: 143,848 | remaining P: 189
# Processed 5,798,504,868 lines | remaining Q: 143,846 | remaining P: 189
# Processed 5,799,004,868 lines | remaining Q: 143,843 | remaining P: 189
# Processed 5,799,504,868 lines | remaining Q: 143,841 | remaining P: 189
# Processed 5,800,004,868 lines | remaining Q: 143,840 | remaining P: 189
# Processed 5,800,504,868 lines | remaining Q: 143,837 | remaining P: 189
# Processed 5,801,004,868 lines | remaining Q: 143,834 | remaining P: 189
# Processed 5,801,504,868 lines | remaining Q: 143,832 | remaining P: 189
# Processed 5,802,004,868 lines | remaining Q: 143,829 | remaining P: 189
# Processed 5,802,504,868 lines | remaining Q: 143,826 | remaining P: 189
# Processed 5,803,004,868 lines | remaining Q: 143,826 | remaining P: 189
# Processed 5,803,504,868 lines | remaining Q: 143,822 | remaining P: 189
# Processed 5,804,004,868 lines | remaining Q: 143,821 | remaining P: 189
# Processed 5,804,504,869 lines | remaining Q: 143,821 | remaining P: 189
# Processed 5,805,004,869 lines | remaining Q: 143,821 | remaining P: 189
# Processed 5,805,504,869 lines | remaining Q: 143,821 | remaining P: 189
# Processed 5,806,004,869 lines | remaining Q: 143,816 | remaining P: 189
# Processed 5,806,504,870 lines | remaining Q: 143,807 | remaining P: 189
# Processed 5,807,004,870 lines | remaining Q: 143,803 | remaining P: 189
# Processed 5,807,504,870 lines | remaining Q: 143,799 | remaining P: 189
# Processed 5,808,004,870 lines | remaining Q: 143,798 | remaining P: 189
# Processed 5,808,504,870 lines | remaining Q: 143,798 | remaining P: 189
# Processed 5,809,004,870 lines | remaining Q: 143,797 | remaining P: 189
# Processed 5,809,504,870 lines | remaining Q: 143,796 | remaining P: 189
# Failed. Will upload next time
# Processed 5,810,004,871 lines | remaining Q: 143,794 | remaining P: 189
# Processed 5,810,504,871 lines | remaining Q: 143,789 | remaining P: 189
# Processed 5,811,004,871 lines | remaining Q: 143,789 | remaining P: 189
# Processed 5,811,504,871 lines | remaining Q: 143,789 | remaining P: 189
# Processed 5,812,004,871 lines | remaining Q: 143,789 | remaining P: 189
# Processed 5,812,504,871 lines | remaining Q: 143,787 | remaining P: 189
# Processed 5,813,004,871 lines | remaining Q: 143,784 | remaining P: 189
# Processed 5,813,504,873 lines | remaining Q: 143,784 | remaining P: 189
# Processed 5,814,004,873 lines | remaining Q: 143,784 | remaining P: 189
# Processed 5,814,504,873 lines | remaining Q: 143,784 | remaining P: 189
# Processed 5,815,004,874 lines | remaining Q: 143,782 | remaining P: 189
# Processed 5,815,504,877 lines | remaining Q: 143,779 | remaining P: 189
# Processed 5,816,004,877 lines | remaining Q: 143,779 | remaining P: 189
# Processed 5,816,504,877 lines | remaining Q: 143,779 | remaining P: 189
# Processed 5,817,004,877 lines | remaining Q: 143,779 | remaining P: 189
# Processed 5,817,504,877 lines | remaining Q: 143,778 | remaining P: 189
# Processed 5,818,004,877 lines | remaining Q: 143,777 | remaining P: 189
# Processed 5,818,504,877 lines | remaining Q: 143,777 | remaining P: 189
# Processed 5,841,004,890 lines | remaining Q: 143,728 | remaining P: 189
# Processed 5,841,504,890 lines | remaining Q: 143,728 | remaining P: 189
# Processed 5,842,004,890 lines | remaining Q: 143,728 | remaining P: 189
# Processed 5,842,504,890 lines | remaining Q: 143,728 | remaining P: 189
# Processed 5,843,004,890 lines | remaining Q: 143,728 | remaining P: 189
# Processed 5,843,504,890 lines | remaining Q: 143,727 | remaining P: 189
# Processed 5,844,004,890 lines | remaining Q: 143,727 | remaining P: 189
# Processed 5,844,504,890 lines | remaining Q: 143,727 | remaining P: 189
# Processed 5,845,004,890 lines | remaining Q: 143,727 | remaining P: 189
# Processed 5,845,504,890 lines | remaining Q: 143,726 | remaining P: 189
# Processed 5,846,004,890 lines | remaining Q: 143,726 | remaining P: 189
# Processed 5,846,504,890 lines | remaining Q: 143,726 | remaining P: 189
# Processed 5,847,004,893 lines | remaining Q: 143,725 | remaining P: 189
# Processed 5,847,504,893 lines | remaining Q: 143,725 | remaining P: 189
# Processed 5,848,004,893 lines | remaining Q: 143,725 | remaining P: 189
# Processed 5,848,504,898 lines | remaining Q: 143,724 | remaining P: 189
# Failed. Will upload next time
# Processed 5,849,004,899 lines | remaining Q: 143,723 | remaining P: 189
# Processed 5,849,504,900 lines | remaining Q: 143,720 | remaining P: 189
# Processed 5,850,004,901 lines | remaining Q: 143,719 | remaining P: 189
# Processed 5,850,504,903 lines | remaining Q: 143,716 | remaining P: 189
# Processed 5,851,004,903 lines | remaining Q: 143,716 | remaining P: 189
# Processed 5,851,504,903 lines | remaining Q: 143,715 | remaining P: 189
# Processed 5,852,004,903 lines | remaining Q: 143,714 | remaining P: 189
# Processed 5,852,504,903 lines | remaining Q: 143,713 | remaining P: 189
# Processed 5,853,004,903 lines | remaining Q: 143,708 | remaining P: 189
# Processed 5,853,504,903 lines | remaining Q: 143,708 | remaining P: 189
# Processed 5,854,004,903 lines | remaining Q: 143,701 | remaining P: 189
# Processed 5,854,504,903 lines | remaining Q: 143,700 | remaining P: 189
# Processed 5,855,004,903 lines | remaining Q: 143,678 | remaining P: 189
# Processed 5,855,504,903 lines | remaining Q: 143,672 | remaining P: 189
# Processed 5,856,004,903 lines | remaining Q: 143,670 | remaining P: 189
# Processed 5,856,504,903 lines | remaining Q: 143,668 | remaining P: 189
# Processed 5,857,004,903 lines | remaining Q: 143,668 | remaining P: 189
# Processed 5,857,504,903 lines | remaining Q: 143,664 | remaining P: 189
# Processed 5,858,004,904 lines | remaining Q: 143,659 | remaining P: 189
# Processed 5,858,504,904 lines | remaining Q: 143,659 | remaining P: 189
# Processed 5,859,004,904 lines | remaining Q: 143,659 | remaining P: 189
# Processed 5,859,504,904 lines | remaining Q: 143,657 | remaining P: 189
# Processed 5,860,004,904 lines | remaining Q: 143,656 | remaining P: 189
# Processed 5,860,504,904 lines | remaining Q: 143,655 | remaining P: 189
# Processed 5,861,004,904 lines | remaining Q: 143,655 | remaining P: 189
# Processed 5,861,504,905 lines | remaining Q: 143,655 | remaining P: 189

# %%
import json
from pathlib import Path

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt


# =========================
# User config
# =========================
DATA_PATH = r"C:\Users\jaden\Downloads\temporal_year_db_monthly.json"
# Examples:
# TARGET = 1793
# TARGET = "1793"
TARGET = "1793-05"
#TARGET = 1793

MAX_EDGES_TO_DRAW = 300
ONLY_LARGEST_COMPONENT = False


# =========================
# Helpers
# =========================
def load_json(path: str) -> dict:
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)


def normalize_target_key(target) -> str:
    """
    Convert the user's target into the string key used in the JSON.

    Examples:
        1793      -> "1793"
        "1793"    -> "1793"
        "1793-05" -> "1793-05"
    """
    return str(target).strip()


def maybe_reduce_for_plot(
    G: nx.MultiDiGraph,
    max_edges: int | None = None,
    largest_component_only: bool = False,
) -> nx.MultiDiGraph:
    H = G

    if largest_component_only and G.number_of_nodes() > 0:
        components = list(nx.connected_components(G.to_undirected()))
        if components:
            largest = max(components, key=len)
            H = G.subgraph(largest).copy()

    if max_edges is not None and H.number_of_edges() > max_edges:
        trimmed = nx.MultiDiGraph()
        for i, (u, v, k, data) in enumerate(H.edges(keys=True, data=True)):
            if i >= max_edges:
                break
            trimmed.add_node(u)
            trimmed.add_node(v)
            trimmed.add_edge(u, v, key=k, **data)
        H = trimmed

    return H


def build_dataframe(triples: list[dict]) -> pd.DataFrame:
    rows = []
    for t in triples:
        head = t.get("head", {})
        tail = t.get("tail", {})

        rows.append(
            {
                "subject_text": head.get("label"),
                "pred_text": t.get("relation"),
                "obj_text": tail.get("label"),
                "start": t.get("start"),
                "end": t.get("end"),
            }
        )

    df = pd.DataFrame(rows)

    if df.empty:
        return df

    df = df[
        df["subject_text"].notna()
        & df["pred_text"].notna()
        & df["obj_text"].notna()
    ].reset_index(drop=True)

    return df


def build_graph(df: pd.DataFrame) -> nx.MultiDiGraph:
    G = nx.MultiDiGraph()

    for _, row in df.iterrows():
        G.add_edge(
            row["subject_text"],
            row["obj_text"],
            label=row["pred_text"],
            start=row["start"],
            end=row["end"],
        )

    return G


def draw_graph(G: nx.MultiDiGraph, target_label: str) -> None:
    if G.number_of_nodes() == 0:
        print(f"No triples to display for {target_label}.")
        return

    plt.figure(figsize=(16, 12))
    pos = nx.spring_layout(G, seed=42, k=1.2)

    nx.draw_networkx_nodes(G, pos, node_size=900)
    nx.draw_networkx_labels(G, pos, font_size=9)
    nx.draw_networkx_edges(
        G,
        pos,
        arrows=True,
        arrowstyle="->",
        arrowsize=15,
        connectionstyle="arc3,rad=0.08",
    )

    edge_labels = {
        (u, v, k): data["label"]
        for u, v, k, data in G.edges(keys=True, data=True)
    }

    nx.draw_networkx_edge_labels(
        G,
        pos,
        edge_labels=edge_labels,
        font_size=8,
        rotate=False,
        label_pos=0.5,
    )

    plt.title(f"Wikidata temporal graph for {target_label}")
    plt.axis("off")
    plt.tight_layout()
    plt.show()


# =========================
# Main
# =========================
def main():
    db = load_json(DATA_PATH)
    target_key = normalize_target_key(TARGET)
    triples = db.get(target_key, [])

    print(f"Triples for {target_key}: {len(triples):,}")
    if not triples:
        print("No data found for that key.")
        return pd.DataFrame(), nx.MultiDiGraph()

    df = build_dataframe(triples)
    print("\nPreview:")
    if df.empty:
        print("No valid rows after filtering.")
        return df, nx.MultiDiGraph()
    print(df.head(20).to_string(index=False))

    G_full = build_graph(df)
    G_draw = maybe_reduce_for_plot(
        G_full,
        max_edges=MAX_EDGES_TO_DRAW,
        largest_component_only=ONLY_LARGEST_COMPONENT,
    )

    print(f"\nGraph nodes: {G_full.number_of_nodes():,}")
    print(f"Graph edges: {G_full.number_of_edges():,}")

    if G_draw.number_of_edges() != G_full.number_of_edges():
        print(
            f"Drawing reduced graph with {G_draw.number_of_nodes():,} nodes and "
            f"{G_draw.number_of_edges():,} edges."
        )

    draw_graph(G_draw, target_key)
    return df, G_full


if __name__ == "__main__":
    df, G = main()
# Out:
# Triples for 1793-05: 90
#
# Preview:
#       subject_text                                        pred_text                       obj_text                start                  end
#  George Washington                                    position held President of the United States 1789-04-30T00:00:00Z 1797-03-04T00:00:00Z
#  George Washington                                    position held                    chairperson 1783-06-19T00:00:00Z 1799-12-14T00:00:00Z
#          Groningen                                          country                 Dutch Republic 1581-01-01T00:00:00Z 1795-01-01T00:00:00Z
#          Yaroslavl                                          country                 Russian Empire 1721-09-10T00:00:00Z 1917-09-13T00:00:00Z
#          Yaroslavl                                       capital of          Yaroslavl Governorate 1777-03-11T00:00:00Z 1929-06-09T00:00:00Z
#          Yaroslavl located in the administrative territorial entity          Yaroslavl Governorate 1777-08-14T00:00:00Z 1929-06-09T00:00:00Z
#            Harburg                                      instance of                           city 1297-01-01T00:00:00Z 1927-07-01T00:00:00Z
#            Bamberg                                          country              Holy Roman Empire 0962-02-07T00:00:00Z 1806-08-06T00:00:00Z
#         Sevastopol                                          country                 Russian Empire 1783-01-01T00:00:00Z 1917-01-01T00:00:00Z
#        Oranienburg                                          country             Kingdom of Prussia 1701-01-01T00:00:00Z 1918-01-01T00:00:00Z
#               Luga                                       capital of                  Luzhsky Uyezd 1777-08-03T00:00:00Z 1927-07-31T00:00:00Z
#               Luga located in the administrative territorial entity                  Luzhsky Uyezd 1777-08-03T00:00:00Z 1927-07-31T00:00:00Z
# Limbach-Oberfrohna                                          country           Electorate of Saxony 1423-01-01T00:00:00Z 1806-01-01T00:00:00Z
#         Birkenwald located in the administrative territorial entity                       Bas-Rhin 1790-03-04T00:00:00Z 1871-01-01T00:00:00Z
#          Buswiller located in the administrative territorial entity                       Bas-Rhin 1790-03-04T00:00:00Z 1871-01-01T00:00:00Z
#          Bourgheim located in the administrative territorial entity                       Bas-Rhin 1790-03-04T00:00:00Z 1871-01-01T00:00:00Z
#           Kirrberg located in the administrative territorial entity                       Bas-Rhin 1790-03-04T00:00:00Z 1871-01-01T00:00:00Z
#          Ohnenheim located in the administrative territorial entity                       Bas-Rhin 1790-03-04T00:00:00Z 1871-01-01T00:00:00Z
#           Rexingen located in the administrative territorial entity                       Bas-Rhin 1790-03-04T00:00:00Z 1871-01-01T00:00:00Z
#     Reipertswiller located in the administrative territorial entity                       Bas-Rhin 1790-03-04T00:00:00Z 1871-01-01T00:00:00Z
#
# Graph nodes: 106
# Graph edges: 90
